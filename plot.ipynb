# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
path = r'ensembleResult/avg' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=1)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame =frame.rename(columns={"avg-fdl": "fdl .1", "avg-fdl.1": "fdl .25","avg-fdl.2": "fdl .5"})
frame
# Out:
#                    Method    fdl .1  std-fdl   avg-tsr  std-tsr   fdl .25  \
# 0                function  0.959184      0.0  0.901408      0.0  0.877551
# 1                    line  0.959184      0.0  0.901408      0.0  0.877551
# 2                  branch  0.959184      0.0  0.901408      0.0  0.918367
# 3                ga_multi  0.959184      0.0  0.901408      0.0  0.877551
# 4       majority ensemble  0.959184      0.0  0.909859      0.0  0.897959
# ..                    ...       ...      ...       ...      ...       ...
# 65                 branch  0.761905      0.0  0.901639      0.0  0.476190
# 66               ga_multi  0.761905      0.0  0.901639      0.0  0.571429
# 67      majority ensemble  0.761905      0.0  0.901639      0.0  0.571429
# 68         union ensemble  0.714286      0.0  0.877049      0.0  0.380952
# 69  intersection ensemble  0.761905      0.0  0.926230      0.0  0.666667
#
#     std-fdl.1  avg-tsr.1  std-tsr.1    fdl .5  std-fdl.2  avg-tsr.2  std-tsr.2
# ...

# %%
frame[frame["Method"] == "function"]

fig = frame.boxplot(by='Method', 
                       column=["fdl .1","fdl .25","fdl .5"], 
                      figsize=(40,10),layout=(1,3))
